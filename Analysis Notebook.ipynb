# %% [markdown]
# # Scheme LangChain

# %%
from langchain.chat_models import google_palm

# %%
from langchain.llms.base import LLM
from langchain.llms.utils import enforce_stop_tokens
from langchain.llms import GooglePalm
from langchain.chains import create_tagging_chain


llm = ChatGooglePalm(google_api_key='AIzaSyA1fu-ob27CzsJozdr6pHd96t5ziaD87wM' , model_name='models/text-bison-001')

schema = {
    "properties" : {
        "name" : {"type" : "string"},
        "email" : {"type" : "string"},
        "age" : {"type" : "string"},
        "height" : {"type" : "integer"},
        "weight" : {"type" : "integer"},
        "phone" : {"type" : "integer"},
        "gender" : {"type" : "string"},
        "address" : {"type" : "string"}
    },
    "required" : ["name" , "email" , "age" , "height" , "weight" , "phone" , "gender" , "address"]
}

chain = create_tagging_chain(schema, llm)

# %%
inp = "I am 23 year old name chethan, with height 123, weight 234, male guy and my phone 64645654, I live in tirupati"

# %%
current_ass = current_ass.replace("{" , "").replace("}" , "").replace("'" , "")

# %%
llm = ChatOpenAI(temperature=0, model="gpt-3.5-turbo-0613" )

# %%
from langchain import LangChain

# Initialize LangChain object
lc = LangChain()

# Define input text
input_text = "Microsoft is acquiring Nuance Communications for $19.7 billion."

# Perform NER
entities = lc.ner(input_text)

# Print the entities
print(entities)

# %%
# Kor!
from kor.extraction import create_extraction_chain
from kor.nodes import Object, Text, Number

# LangChain Models
from langchain.chat_models import ChatOpenAI
from langchain.llms import OpenAI

# Standard Helpers
import pandas as pd
import requests
import time
import json
from datetime import datetime

# Text Helpers
from bs4 import BeautifulSoup
from markdownify import markdownify as md

# For token counting
from langchain.callbacks import get_openai_callback

def printOutput(output):
    print(json.dumps(output,sort_keys=True, indent=3))

# %%
pip install promptify
# Out:
# Collecting promptify
#   Downloading promptify-2.0.3.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Collecting openai==0.27.0 (from promptify)
#   Downloading openai-0.27.0-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 kB 2.5 MB/s eta 0:00:00
# Collecting cohere==4.13.1 (from promptify)
#   Obtaining dependency information for cohere==4.13.1 from https://files.pythonhosted.org/packages/71/9b/61192463d51e3b329981bb99e34c8e5603408d98343350da6d54c2d77efa/cohere-4.13.1-py3-none-any.whl.metadata
#   Downloading cohere-4.13.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting anthropic==0.3.4 (from promptify)
#   Obtaining dependency information for anthropic==0.3.4 from https://files.pythonhosted.org/packages/20/8e/5f7ce26feb891791569e9765103d99731ff79108ec81876c2217bd19633f/anthropic-0.3.4-py3-none-any.whl.metadata
#   Downloading anthropic-0.3.4-py3-none-any.whl.metadata (10 kB)
# Collecting regex==2022.10.31 (from promptify)
#   Using cached regex-2022.10.31-cp310-cp310-macosx_11_0_arm64.whl (287 kB)
# Requirement already satisfied: appdirs==1.4.4 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from promptify) (1.4.4)
# Collecting jinja2==2.11.3 (from promptify)
#   Using cached Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
# Collecting markupsafe==2.0.1 (from promptify)
#   Downloading MarkupSafe-2.0.1-cp310-cp310-macosx_10_9_universal2.whl (18 kB)
# Collecting huggingface_hub==0.12 (from promptify)
#   Downloading huggingface_hub-0.12.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 kB 3.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting pytest==7.2.2 (from promptify)
#   Downloading pytest-7.2.2-py3-none-any.whl (317 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.2/317.2 kB 2.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Requirement already satisfied: tenacity==8.2.2 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from promptify) (8.2.2)
# Requirement already satisfied: tiktoken==0.4.0 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from promptify) (0.4.0)
# Collecting tqdm==4.65.0 (from promptify)
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Requirement already satisfied: anyio<4,>=3.5.0 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from anthropic==0.3.4->promptify) (3.7.0)
# Collecting distro<2,>=1.7.0 (from anthropic==0.3.4->promptify)
#   Using cached distro-1.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from anthropic==0.3.4->promptify) (0.24.1)
# Requirement already satisfied: pydantic<2.0.0,>=1.9.0 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from anthropic==0.3.4->promptify) (1.10.12)
# Requirement already satisfied: tokenizers>=0.13.0 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from anthropic==0.3.4->promptify) (0.13.3)
# Requirement already satisfied: typing-extensions<5,>=4.1.1 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from anthropic==0.3.4->promptify) (4.7.1)
# Requirement already satisfied: aiohttp<4.0,>=3.0 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from cohere==4.13.1->promptify) (3.8.5)
# Requirement already satisfied: backoff<3.0,>=2.0 in /Users/achethanreddy/.local/lib/python3.10/site-packages (from cohere==4.13.1->promptify) (2.2.1)
# Requirement already satisfied: importlib_metadata<7.0,>=6.0 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from cohere==4.13.1->promptify) (6.8.0)
# Requirement already satisfied: requests<3.0.0,>=2.25.0 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from cohere==4.13.1->promptify) (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from cohere==4.13.1->promptify) (1.26.16)
# Requirement already satisfied: filelock in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from huggingface_hub==0.12->promptify) (3.12.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from huggingface_hub==0.12->promptify) (6.0)
# Requirement already satisfied: packaging>=20.9 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from huggingface_hub==0.12->promptify) (23.1)
# Requirement already satisfied: attrs>=19.2.0 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from pytest==7.2.2->promptify) (23.1.0)
# Collecting iniconfig (from pytest==7.2.2->promptify)
#   Using cached iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from pytest==7.2.2->promptify) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from pytest==7.2.2->promptify) (1.1.1)
# Requirement already satisfied: tomli>=1.0.0 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from pytest==7.2.2->promptify) (2.0.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from aiohttp<4.0,>=3.0->cohere==4.13.1->promptify) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from aiohttp<4.0,>=3.0->cohere==4.13.1->promptify) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from aiohttp<4.0,>=3.0->cohere==4.13.1->promptify) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from aiohttp<4.0,>=3.0->cohere==4.13.1->promptify) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from aiohttp<4.0,>=3.0->cohere==4.13.1->promptify) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from aiohttp<4.0,>=3.0->cohere==4.13.1->promptify) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from anyio<4,>=3.5.0->anthropic==0.3.4->promptify) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from anyio<4,>=3.5.0->anthropic==0.3.4->promptify) (1.3.0)
# Requirement already satisfied: certifi in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from httpx<1,>=0.23.0->anthropic==0.3.4->promptify) (2023.7.22)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from httpx<1,>=0.23.0->anthropic==0.3.4->promptify) (0.17.2)
# Requirement already satisfied: zipp>=0.5 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from importlib_metadata<7.0,>=6.0->cohere==4.13.1->promptify) (3.16.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from httpcore<0.18.0,>=0.15.0->httpx<1,>=0.23.0->anthropic==0.3.4->promptify) (0.14.0)
# Downloading anthropic-0.3.4-py3-none-any.whl (793 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.6/793.6 kB 1.9 MB/s eta 0:00:00 MB/s eta 0:00:01:01m
# Downloading cohere-4.13.1-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 3.4 MB/s eta 0:00:00
# Building wheels for collected packages: promptify
#   Building wheel for promptify (setup.py) ... done
#   Created wheel for promptify: filename=promptify-2.0.3-py3-none-any.whl size=60855 sha256=7cc57a32fdb1624a8894e4b3398bf760f7eac5c371133792dbe8888759e472c5
#   Stored in directory: /Users/achethanreddy/Library/Caches/pip/wheels/e9/09/29/7137907a26c683794a32a7640dd3ac828793de7af9134ff9a2
# Successfully built promptify
# Installing collected packages: tqdm, regex, markupsafe, iniconfig, distro, pytest, jinja2, huggingface_hub, openai, cohere, anthropic, promptify
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: regex
#     Found existing installation: regex 2023.6.3
#     Uninstalling regex-2023.6.3:
#       Successfully uninstalled regex-2023.6.3
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.1.3
#     Uninstalling MarkupSafe-2.1.3:
#       Successfully uninstalled MarkupSafe-2.1.3
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.2
#     Uninstalling Jinja2-3.1.2:
#       Successfully uninstalled Jinja2-3.1.2
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.15.1
#     Uninstalling huggingface-hub-0.15.1:
#       Successfully uninstalled huggingface-hub-0.15.1
#   Attempting uninstall: openai
#     Found existing installation: openai 0.27.10
#     Uninstalling openai-0.27.10:
#       Successfully uninstalled openai-0.27.10
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.31.0 requires huggingface-hub<1.0,>=0.14.1, but you have huggingface-hub 0.12.0 which is incompatible.
# apache-beam 2.50.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.7 which is incompatible.
# datasets 2.11.0 requires dill<0.3.7,>=0.3.0, but you have dill 0.3.7 which is incompatible.
# flask 2.3.3 requires Jinja2>=3.1.2, but you have jinja2 2.11.3 which is incompatible.
# gradio 3.35.2 requires huggingface-hub>=0.14.0, but you have huggingface-hub 0.12.0 which is incompatible.
# gradio-client 0.2.7 requires huggingface-hub>=0.13.0, but you have huggingface-hub 0.12.0 which is incompatible.
# kor 0.13.0 requires pandas<2.0.0,>=1.5.3, but you have pandas 2.1.0 which is incompatible.
# nbconvert 7.5.0 requires jinja2>=3.0, but you have jinja2 2.11.3 which is incompatible.
# textbase-client 0.1.2 requires openai<0.28.0,>=0.27.8, but you have openai 0.27.0 which is incompatible.
# textbase-client 0.1.2 requires pydantic<3.0.0,>=2.3.0, but you have pydantic 1.10.12 which is incompatible.
# werkzeug 2.3.7 requires MarkupSafe>=2.1.1, but you have markupsafe 2.0.1 which is incompatible.
# Successfully installed anthropic-0.3.4 cohere-4.13.1 distro-1.8.0 huggingface_hub-0.12.0 iniconfig-2.0.0 jinja2-2.11.3 markupsafe-2.0.1 openai-0.27.0 promptify-2.0.3 pytest-7.2.2 regex-2022.10.31 tqdm-4.65.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import promptify

# %%
promptify.

# %%
from promptify import Goo

# %%
from promptify import Prompter,OpenAI, Pipeline

sentence     =  """The patient is a 93-year-old female with a medical  				 
                history of chronic right hip pain, osteoporosis,					
                hypertension, depression, and chronic atrial						
                fibrillation admitted for evaluation and management				
                of severe nausea and vomiting and urinary tract				
                infection"""

model        = OpenAI(api_key) # or `HubModel()` for Huggingface-based inference or 'Azure' etc
prompter     = Prompter('ner.jinja') # select a template or provide custom template
pipe         = Pipeline(prompter , model)


result = pipe.fit(sentence, domain="medical", labels=None)


### Output

[
    {"E": "93-year-old", "T": "Age"},
    {"E": "chronic right hip pain", "T": "Medical Condition"},
    {"E": "osteoporosis", "T": "Medical Condition"},
    {"E": "hypertension", "T": "Medical Condition"},
    {"E": "depression", "T": "Medical Condition"},
    {"E": "chronic atrial fibrillation", "T": "Medical Condition"},
    {"E": "severe nausea and vomiting", "T": "Symptom"},
    {"E": "urinary tract infection", "T": "Medical Condition"},
    {"Branch": "Internal Medicine", "Group": "Geriatrics"},
]

# %%
from langchain.chat_models import ChatGooglePalm

# %%
from langchain.chat_models  import google_palm

# %%
import langchain

# %%
langchain.chat_models

# %%
models/chat-bison-001
models/text-bison-001
models/embedding-gecko-001

# %%
from langchain.chat_models import ChatGooglePalm
from langchain.chains import create_tagging_chain, create_tagging_chain_pydantic
from langchain.prompts import ChatPromptTemplate

# %%
llm = ChatGooglePalm(temperature=0, 
                     model="models/text-bison-001" , 
                     google_api_key="AIzaSyA1fu-ob27CzsJozdr6pHd96t5ziaD87wM")

# %%
schema = {
    "properties": {
        "sentiment": {"type": "string"},
        "stars": {"type": "integer"},
        "language": {"type": "string"},
    }
}

# %%
chain = create_tagging_chain(schema, llm)

# %%
chain.prompt.messages[0].prompt
# Out:
# PromptTemplate(input_variables=['input'], output_parser=None, partial_variables={}, template="Extract the desired information from the following passage.\n\nOnly extract the properties mentioned in the 'information_extraction' function.\n\nPassage:\n{input}\n", template_format='f-string', validate_template=True)

# %%
print(chain.prompt.messages[0].prompt.template)
# Out:
# Extract the desired information from the following passage.
#
# Only extract the properties mentioned in the 'information_extraction' function.
#
# Passage:
# {input}

# %%
raw_text = inp
prompt = '''Extract the desired information from the following passage.

Only extract the properties mentioned in the 'information_extraction' function.

Passage:
{raw_text}

schema = {{
    "properties" : {{
        "name" : {{"type" : "string"}},
        "email" : {{"type" : "string"}},
        "age" : {{"type" : "string"}},
        "height" : {{"type" : "integer"}},
        "weight" : {{"type" : "integer"}},
        "phone" : {{"type" : "integer"}},
        "gender" : {{"type" : "string"}},
        "address" : {{"type" : "string"}}
    }},
    "required" : ["name" , "email" , "age" , "height" , "weight" , "phone" , "gender" , "address"]
}}
'''

# %%
print(prompt)
# Out:
# Extract the desired information from the following passage.
#
# Only extract the properties mentioned in the 'information_extraction' function.
#
# Passage:
# I am 23 year old name chethan, with height 123, weight 234, male guy and my phone 64645654, I live in tirupati
#
# schema = {
#     "properties" : {
#         "name" : {"type" : "string"},
#         "email" : {"type" : "string"},
#         "age" : {"type" : "string"},
#         "height" : {"type" : "integer"},
#         "weight" : {"type" : "integer"},
#         "phone" : {"type" : "integer"},
#         "gender" : {"type" : "string"},
#         "address" : {"type" : "string"}
#     },
#     "required" : ["name" , "email" , "age" , "height" , "weight" , "phone" , "gender" , "address"]
# }

# %%
from langchain.llms import GooglePalm
from langchain import PromptTemplate, HuggingFaceHub, LLMChain
Palm = GooglePalm(temperature=0, 
                     model="models/text-bison-001" , 
                     google_api_key="AIzaSyA1fu-ob27CzsJozdr6pHd96t5ziaD87wM")

# %%
template = prompt

# %%
prompt = PromptTemplate(template=template, input_variables=["raw_text"])

# %%
llm_chain = LLMChain(
    prompt=prompt,
    llm=Palm
)

# %%
inp
# Out:
# 'I am 23 year old name chethan, with height 123, weight 234, male guy and my phone 64645654, I live in tirupati'

# %%
res = llm_chain.run(inp)

# %%
import json
json.loads(res)
# Out:
# {'name': 'chethan',
#  'age': '23',
#  'height': '123',
#  'weight': '234',
#  'phone': '64645654',
#  'gender': 'male',
#  'address': 'tirupati'}

# %%
chain.llm_kwargs
# Out:
# {'functions': [{'name': 'information_extraction',
#    'description': 'Extracts the relevant information from the passage.',
#    'parameters': {'type': 'object',
#     'properties': {'sentiment': {'title': 'sentiment', 'type': 'string'},
#      'stars': {'title': 'stars', 'type': 'integer'},
#      'language': {'title': 'language', 'type': 'string'}},
#     'required': []}}],
#  'function_call': {'name': 'information_extraction'}}

# %%
chain.output_parser
# Out:
# JsonOutputFunctionsParser(args_only=True, strict=False)

# %%
google_palm.ChatGooglePalm?

# %%
google_palm.ChatGooglePalm(google_api_key='AIzaSyA1fu-ob27CzsJozdr6pHd96t5ziaD87wM')
# Out:
# ChatGooglePalm(cache=None, verbose=False, callbacks=None, callback_manager=None, tags=None, metadata=None, client=<module 'google.generativeai' from '/Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages/google/generativeai/__init__.py'>, model_name='models/chat-bison-001', google_api_key='AIzaSyA1fu-ob27CzsJozdr6pHd96t5ziaD87wM', temperature=None, top_p=None, top_k=None, n=1)

# %%
# importing required modules
from PyPDF2 import PdfReader
  
# creating a pdf reader object
reader = PdfReader('billing_slip.pdf')
  
# printing number of pages in pdf file
print(len(reader.pages))
  
# getting a specific page from the pdf file
page = reader.pages[0]
  
# extracting text from page
text = page.extract_text()
print(text)
# Out:
# 1
# Intermediate Ring Road, Domlur
#  Embassy Golf Links Road, Challaghatta
#  Bengaluru, Karnataka 560071
#
# Bill No:
# BS12345
# Patient ID:
# PAT12345
# Date:
# 2023-07-28
# Name:
# John Doe
# Address:
# 123 Main Street, Cityville
# Cell No:
# 9876543210
# Amount Paid:
# $200.00
# Number of Days
# 10
# Thank you for choosing our services. For any queries, please contact us at 04182 - 222527.

# %%
from pymongo.mongo_client import MongoClient

Key_Mongo_Cloud = "mongodb://aioverflow:12345@ac-pu6wews-shard-00-00.me4dkct.mongodb.net:27017,ac-pu6wews-shard-00-01.me4dkct.mongodb.net:27017,ac-pu6wews-shard-00-02.me4dkct.mongodb.net:27017/?ssl=true&replicaSet=atlas-jcoztp-shard-0&authSource=admin&retryWrites=true&w=majority"
Key_Mongo_Local = "mongodb://localhost:27017/"

Data = MongoClient(Key_Mongo_Cloud)
currId = Data['HoepHackathon']['PatientID']

# %%
currId.insert_one({"PatientID" : "23MED001"})

# %%
import urllib.parse
import json 

# Define the file path
file_path = 'restructured_exercise.json'

# Load the JSON data from the file
with open(file_path, 'r') as json_file:
    json_data = json.load(json_file)

# Now json_data contains the loaded JSON content
# You can access it like a regular Python dictionary

# Iterate through the JSON data
for category, exercises in json_data.items():
    for exercise in exercises:
        title = exercise["Title"]
        try:
            videosSearch = VideosSearch(title+" "+"exercise", limit = 1)
            res = videosSearch.result()
            exercise['Link'] = res['result'][0]['link']
        except:
            exercise['Link'] = "https://www.youtube.com/watch?v=jQQ_yOVenRs&ab_channel=PrismaHealth"


print(json_data)
# Out:
# {'Lateral Hip': [{'Title': 'Side Lying Both Leg Straight Leg Abduction With Loop', 'Link': 'https://www.youtube.com/watch?v=RwH43Qdgcbo'}, {'Title': 'Dog Pose Leg Abduction (wall Support)', 'Link': 'https://www.youtube.com/watch?v=OR_U5qYjB_w'}, {'Title': 'Standing Leg Abduction With Loop', 'Link': 'https://www.youtube.com/watch?v=mnYtck8MMYM'}, {'Title': 'Dog Pose Leg Abduction With Loop', 'Link': 'https://www.youtube.com/watch?v=BXQTHA2deQQ'}, {'Title': 'Small Knee Bend Led Abduction With Loop Without Support', 'Link': 'https://www.youtube.com/watch?v=GcOsgIduYvQ'}, {'Title': 'Small Knee Bend Unilateral Leg Abduction', 'Link': 'https://www.youtube.com/watch?v=k8aDn-MfGoI'}, {'Title': 'Supine Leg Drop With Loop', 'Link': 'https://www.youtube.com/watch?v=GcOsgIduYvQ'}, {'Title': 'Small Knee Bend Unilateral Leg Abduction (with Loop)', 'Link': 'https://www.youtube.com/watch?v=GcOsgIduYvQ'}, {'Title': '90-90 Bilateral Leg Drop With Loop', 'Link': 'https://www.youtube.com/watch?v=-cQqV5q52FQ'}, {'Title': 'Side Lying Leg Abduction With Loop Above Hip Level', 'Link': 'https://www.youtube.com/watch?v=BXQTHA2deQQ'}, {'Title': 'Side Lying Straight Leg Abduction With Loop', 'Link': 'https://www.youtube.com/watch?v=RwH43Qdgcbo'}, {'Title': 'Sdie Lying Leg Abduction With Loop', 'Link': 'https://www.youtube.com/watch?v=RwH43Qdgcbo'}, {'Title': 'Side Plank Leg Abduction With Loop', 'Link': 'https://www.youtube.com/watch?v=Om3M4ezJvSM'}, {'Title': 'Side Lying Straight Leg Abduction Above The Hip Level', 'Link': 'https://www.youtube.com/watch?v=_-wMPb451Iw'}, {'Title': 'Partial Side Plank With Leg Abduction With Loop', 'Link': 'https://www.youtube.com/watch?v=Om3M4ezJvSM'}, {'Title': 'Small Knee Bend Bilateral Leg Abduction', 'Link': 'https://www.youtube.com/watch?v=yntoiRjuZ0k'}, {'Title': 'Side Lying Leg Abduction', 'Link': 'https://www.youtube.com/watch?v=g9FtnmsIYgI'}, {'Title': 'Small Knee Bend Leg Abduction With Loop With Heel Off', 'Link': 'https://www.youtube.com/watch?v=gBFcAdlYhBI'}, {'Title': 'Side Lying Straight Leg Abduction', 'Link': 'https://www.youtube.com/watch?v=g9FtnmsIYgI'}], 'warm up': [{'Title': 'Side Monster Walk', 'Link': 'https://www.youtube.com/watch?v=Nry0TZg8EN0'}, {'Title': 'Toe Walk Sideways', 'Link': 'https://www.youtube.com/watch?v=5kdFBlgzjS8'}, {'Title': 'Heel Walk', 'Link': 'https://www.youtube.com/watch?v=ZRI899Xv8PE'}, {'Title': 'Heel Walk-sideways', 'Link': 'https://www.youtube.com/watch?v=au2EJaVtji4'}, {'Title': 'Flexibility-1', 'Link': 'https://www.youtube.com/watch?v=wCsvZwK_e_8'}, {'Title': 'Single Leg Hamstring Stretch', 'Link': 'https://www.youtube.com/watch?v=n-cavPgdkLA'}, {'Title': 'Heel Walk-1', 'Link': 'https://www.youtube.com/watch?v=KLvHb02X6wU'}, {'Title': 'Modified Push Up', 'Link': 'https://www.youtube.com/watch?v=SVfWdQTyEMs'}, {'Title': 'Monster Walk With Loop', 'Link': 'https://www.youtube.com/watch?v=Nry0TZg8EN0'}, {'Title': 'Side Monster Walk With Loop', 'Link': 'https://www.youtube.com/watch?v=Nry0TZg8EN0'}, {'Title': 'Toe Walk', 'Link': 'https://www.youtube.com/watch?v=5Roy5sEReT4'}, {'Title': 'Small Knee Bend Hip Anduction With Loop', 'Link': 'https://www.youtube.com/watch?v=GcOsgIduYvQ'}, {'Title': 'Monster Walk', 'Link': 'https://www.youtube.com/watch?v=Nry0TZg8EN0'}], 'Primal Moves': [{'Title': 'Four Point Gait Knee Off', 'Link': 'https://www.youtube.com/watch?v=T5qflbruDBs'}, {'Title': 'Partial Side Plank With Leg Abduction', 'Link': 'https://www.youtube.com/watch?v=BLQESHENRLg'}, {'Title': 'Primal Move-2', 'Link': 'https://www.youtube.com/watch?v=0lb6hfFvsZw'}, {'Title': 'Primal Move-3', 'Link': 'https://www.youtube.com/watch?v=0W96v-xrvP4'}, {'Title': 'Partial Side Plank With Reps', 'Link': 'https://www.youtube.com/watch?v=3U0Q0lKDrxQ'}, {'Title': 'Primal Move -1', 'Link': 'https://www.youtube.com/watch?v=x3WZN49imMU'}, {'Title': 'Four Point Gait Knee Off Move', 'Link': 'https://www.youtube.com/watch?v=ElZkPye4WtA'}], 'Posterior Hip': [{'Title': 'Single Leg Small Knee Bend W ...

# %%
# Define the file path
file_path = 'restructured_exercise.json'

# Save the dictionary as JSON
with open(file_path, 'w') as json_file:
    json.dump(json_data, json_file)

# %%
import requests
from bs4 import BeautifulSoup

def findYT(search):
    search_param = {'search_query': search}
    search_result = requests.get('https://www.youtube.com/results', params=search_param, cookies={'CONSENT': 'YES+42'}).text
    # Just writes to a temp file so you can inspect the code 
    with open("tmp.txt", "w") as f:
        f.write(search_result)
        f.close()
    return search_result

print(findYT("Neck exercise"))
# Out:
# <!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="en-GB" system-icons typography typography-spacing darker-dark-theme darker-dark-theme-deprecate><head><script data-id="_gd" nonce="cufSBo5PyXrS9OrHhOuGzA">window.WIZ_global_data = {"MuJWjd":false,"nQyAE":{},"oxN3nb":{"1":false}};</script><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="origin-trial" content="ApvK67ociHgr2egd6c2ZjrfPuRs8BHcvSggogIOPQNH7GJ3cVlyJ1NOq/COCdj0+zxskqHt9HgLLETc8qqD+vwsAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2OTUxNjc5OTksImlzU3ViZG9tYWluIjp0cnVlfQ=="/><script nonce="cufSBo5PyXrS9OrHhOuGzA">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else{var k;for(k in a[0])ytcfg.d()[k]=a[0][k]}}};
# window.ytcfg.set('EMERGENCY_BASE_URL', '\/error_204?t\x3djserror\x26level\x3dERROR\x26client.name\x3d1\x26client.version\x3d2.20230914.04.00');</script><script nonce="cufSBo5PyXrS9OrHhOuGzA">(function(){window.yterr=window.yterr||true;window.unhandledErrorMessages={};window.unhandledErrorCount=0;
# window.onerror=function(msg,url,line,columnNumber,error){var err;if(error)err=error;else{err=new Error;err.stack="";err.message=msg;err.fileName=url;err.lineNumber=line;if(!isNaN(columnNumber))err["columnNumber"]=columnNumber}var message=String(err.message);if(!err.message||message in window.unhandledErrorMessages||window.unhandledErrorCount>=5)return;window.unhandledErrorCount+=1;window.unhandledErrorMessages[message]=true;var img=new Image;window.emergencyTimeoutImg=img;img.onload=img.onerror=function(){delete window.emergencyTimeoutImg};
# var combinedLineAndColumn=err.lineNumber;if(!isNaN(err["columnNumber"]))combinedLineAndColumn=combinedLineAndColumn+(":"+err["columnNumber"]);var stack=err.stack||"";var values={"msg":message,"type":err.name,"client.params":"unhandled window error","file":err.fileName,"line":combinedLineAndColumn,"stack":stack.substr(0,500)};var thirdPartyScript=!err.fileName||err.fileName==="<anonymous>"||stack.indexOf("extension://")>=0;var replaced=stack.replace(/https:\/\/www.youtube.com\//g,"");if(replaced.match(/https?:\/\/[^/]+\//))thirdPartyScript=
# true;else if(stack.indexOf("trapProp")>=0&&stack.indexOf("trapChain")>=0)thirdPartyScript=true;else if(message.indexOf("redefine non-configurable")>=0)thirdPartyScript=true;var baseUrl=window["ytcfg"].get("EMERGENCY_BASE_URL","https://www.youtube.com/error_204?t=jserror&level=ERROR");var unsupported=message.indexOf("window.customElements is undefined")>=0;if(thirdPartyScript||unsupported)baseUrl=baseUrl.replace("level=ERROR","level=WARNING");var parts=[baseUrl];var key;for(key in values){var value=
# values[key];if(value)parts.push(key+"="+encodeURIComponent(value))}img.src=parts.join("&")};
# (function(){function _getExtendedNativePrototype(tag){var p=this._nativePrototypes[tag];if(!p){p=Object.create(this.getNativePrototype(tag));var p$=Object.getOwnPropertyNames(window["Polymer"].Base);var i=0;var n=void 0;for(;i<p$.length&&(n=p$[i]);i++)if(!window["Polymer"].BaseDescriptors[n])try{p[n]=window["Polymer"].Base[n]}catch(e){throw new Error("Error while copying property: "+n+". Tag is "+tag);}try{Object.defineProperties(p,window["Polymer"].BaseDescriptors)}catch(e){throw new Error("Polymer define property failed for "+
# Object.keys(p));}this._nativePrototypes[tag]=p}return p}function handlePolymerError(msg){window.onerror(msg,window.location.href,0,0,new Error(Array.prototype.join.call(arguments,",")))}var origPolymer=window["Polymer"];var newPolymer=function(config){if(!origPolymer._ytIntercepted&&window["Polymer"].Base){origPolymer._ytIntercepted=true;window["Polymer"].Base._getExtendedNativePrototype=_getExtendedNativePrototype;window["Polymer"].Base._error=handlePolymerError;window["Polymer"].Base._warn=handlePolymerError}return origPolymer.apply(this,
# arguments)};var origDescriptor=Object.getOwnPropertyDescriptor(window,"Polymer");Object.defineProperty(window,"Polymer",{set:function(p){if(origDescriptor&&origDescriptor.set&&origDescriptor.get){origDescriptor.set(p);origPolymer=origDescriptor.get()}else origPolymer=p;if(typeof origPolymer==="function")Object.defineProperty(window,"Polymer",{value:origPolymer,configurable:true,enumerable:true,writable:true})},get:function(){return typeof origPolymer==="function"?newPolymer:origPolymer},configurable:true,
# enumerable:true})})();}).call(this);
# </script><script nonce="cufSBo5PyXrS9OrHhOuGzA">window.Polymer=window.Polymer||{};window.Polymer.legacyOptimizations=true;window.Polymer.setPassiveTouchGestures=true;window.ShadyDOM={force:true,preferPerformance:true,noPatch:true};
# window.polymerSkipLoadingFontRoboto = true;</script><link rel="shortcut icon" href="https://www.youtube.com/s/desktop/dbf5c200/img/favicon.ico" type="image/x-icon"><link rel="icon" href="https://www.youtube.com/s/desktop/dbf5c200/img/favicon_32x32.png" sizes="32x32"><link rel="icon" href="https://www.youtube.com/s/desktop/dbf5c200/img/favicon_48x48.png" sizes="48x48"><link rel="icon" href="https://www.youtube.com/s/desktop/dbf5c200/img/favicon_96x96.png" sizes="96x96"><link rel="icon" href="https://www.youtube.com/s/desktop/dbf5c200/img/favicon_144x144.png" sizes="144x144"><script nonce="cufSBo5PyXrS9OrHhOuGzA">if ('undefined' == typeof Symbol || 'undefined' == typeof Symbol.iterator) {delete Array.prototype.entries;}</script><script nonce="cufSBo5PyXrS9OrHhOuGzA">var ytcsi={gt:function(n){n=(n||"")+"data_";return ytcsi[n]||(ytcsi[n]={tick:{},info:{}})},now:window.performance&&window.performance.timing&&window.performance.now&&window.performance.timing.navigationStart?function(){return window.performance.timing.navigationStart+window.performance.now()}:function(){return(new Date).getTime()},tick:function(l,t,n){var ticks=ytcsi.gt(n).tick;var v=t||ytcsi.now();if(ticks[l]){ticks["_"+l]=ticks["_"+l]||[ticks[l]];ticks["_"+l].push(v)}ticks[l]=v},info:function(k,
# v,n){ytcsi.gt(n).info[k]=v},setStart:function(t,n){ytcsi.tick("_start",t,n)}};
# (function(w,d){function isGecko(){if(!w.navigator)return false;try{if(w.navigator.userAgentData&&w.navigator.userAgentData.brands&&w.navigator.userAgentData.brands.length){var brands=w.navigator.userAgentData.brands;var i=0;for(;i<brands.length;i++)if(brands[i]&&brands[i].brand==="Firefox")return true;return false}}catch(e){setTimeout(function(){throw e;})}if(!w.navigator.userAgent)return false;var ua=w.navigator.userAgent;return ua.indexOf("Gecko")>0&&ua.toLowerCase().indexOf("webkit")<0&&ua.indexOf("Edge")<
# 0&&ua.indexOf("Trident")<0&&ua.indexOf("MSIE")<0}ytcsi.setStart(w.performance?w.performance.timing.responseStart:null);var isPrerender=(d.visibilityState||d.webkitVisibilityState)=="prerender";var vName=!d.visibilityState&&d.webkitVisibilityState?"webkitvisibilitychange":"visibilitychange";if(isPrerender){var startTick=function(){ytcsi.setStart();d.removeEventListener(vName,startTick)};d.addEventListener(vName,startTick,false)}if(d.addEventListener)d.addEventListener(vName,function(){ytcsi.tick("vc")},
# false);if(isGecko()){var isHidden=(d.visibilityState||d.webkitVisibilityState)=="hidden";if(isHidden)ytcsi.tick("vc")}var slt=function(el,t){setTimeout(function(){var n=ytcsi.now();el.loadTime=n;if(el.slt)el.slt()},t)};w.__ytRIL=function(el){if(!el.getAttribute("data-thumb"))if(w.requestAnimationFrame)w.requestAnimationFrame(function(){slt(el,0)});else slt(el,16)}})(window,document);
# </script><script nonce="cufSBo5PyXrS9OrHhOuGzA">(function() {var img = new Image().src = "https://i.ytimg.com/generate_204";})();</script><script src="https://www.youtube.com/s/desktop/dbf5c200/jsbin/web-animations-next-lite.min.vflset/web-animations-next-lite.min.js" nonce="cufSBo5PyXrS9OrHhOuGzA"></script><script src="https://www.youtube.com/s/desktop/dbf5c200/jsbin/webcomponents-all-noPatch.vflset/webcomponents-all-noPatch.js" nonce="cufSBo5PyXrS9OrHhOuGzA"></script><script src="https://www.youtube.com/s/desktop/dbf5c200/jsbin/fetch-polyfill.vflset/fetch-polyfill.js" nonce="cufSBo5PyXrS9OrHhOuGzA"></script><script src="https://www.youtube.com/s/desktop/dbf5c200/jsbin/intersection-observer.min.vflset/intersection-observer.min.js" nonce="cufSBo5PyXrS9OrHhOuGzA"></script><script nonce="cufSBo5PyXrS9OrHhOuGzA">if (window.ytcsi) {window.ytcsi.tick('lpcs', null, '');}</script><script nonce="cufSBo5PyXrS9OrHhOuGzA">(function() {window.ytplayer={};
# ytcfg.set({"CLIENT_CANARY_STATE":"none","DEVICE":"cbrand\u003dpython\u0026ceng\u003dUSER_DEFINED\u0026cmodel\u003drequests\u0026cplatform\u003dDESKTOP","DISABLE_YT_IMG_DELAY_LOADING":false,"ELEMENT_POOL_DEFAULT_CAP":75,"EVENT_ID":"MMIGZdClGMWKz7sP4OaF6Ag","EXPERIMENT_FLAGS":{"H5_enable_full_pacf_logging":true,"H5_use_async_logging":true,"action_companion_center_align_description":true,"allow_skip_networkless":true,"att_web_record_metrics":true,"autoescape_tempdata_url":true,"browse_next_continuations_migration_playlist":true,"c3_watch_page_component":true,"cache_utc_offset_minutes_in_pref_cookie":true,"cancel_pending_navs":true,"check_user_lact_at_prompt_shown_time_on_web":true,"clear_user_partitioned_ls":true,"client_respect_autoplay_switch_button_renderer":true,"cold_missing_history":true,"compress_gel":true,"config_age_report_killswitch":true,"csi_on_gel":true,"decorate_autoplay_renderer":true,"defer_menus":true,"defer_overlays":true,"defer_rendering_outside_visible_area":true,"deprecate_csi_has_info":true,"deprecate_pair_servlet_enabled":true,"desktop_add_to_playlist_renderer_dialog_popup":true,"desktop_animate_miniplayer":true,"desktop_client_release":true,"desktop_delay_player_resizing":true,"desktop_enable_dmpanel_click_drag_scroll":true,"desktop_enable_dmpanel_scroll":true,"desktop_enable_dmpanel_wheel_scroll":true,"desktop_image_cta_no_background":true,"desktop_keyboard_capture_keydown_killswitch":true,"desktop_log_img_click_location":true,"desktop_mix_use_sampled_color_for_bottom_bar":true,"desktop_mix_use_sampled_color_for_bottom_bar_search":true,"desktop_mix_use_sampled_color_for_bottom_bar_watch_next":true,"desktop_notification_high_priority_ignore_push":true,"desktop_notification_set_title_bar":true,"desktop_persistent_menu":true,"desktop_search_no_spacing_pos_zero":true,"desktop_search_prominent_thumbs":true,"desktop_sparkles_light_cta_button":true,"desktop_swipeable_guide":true,"desktop_themeable_vulcan":true,"desktop_use_new_history_manager":true,"disable_child_node_auto_formatted_strings":true,"disable_dependency_injection":true,"disable_features_for_supex":true,"disable_legacy_desktop_remote_queue":true,"disable_pacf_logging_for_memory_limited_tv":true,"disable_simple_mixed_direction_formatted_strings":true,"disable_super_chat_buy_button":true,"disable_thumbnail_preloading":true,"embeds_web_nwl_disable_nocookie":true,"empty_string_check_for_load_data":true,"enable_ab_report_on_errorscreen":true,"enable_ab_rp_int":true,"enable_ata_dialog_all_web":true,"enable_buenos_aires_page_header_mini_app_dest":true,"enable_button_behavior_reuse":true,"enable_call_to_action_clarification_renderer_bottom_section_conditions":true,"enable_channel_page_modern_profile_section":true,"enable_cinematic_blur_desktop_loading":true,"enable_client_sli_logging":true,"enable_client_streamz_web":true,"enable_desktop_amsterdam_info_panels":true,"enable_dismiss_loading_manually":true,"enable_dma_web_toast":true,"enable_docked_chat_messages":true,"enable_dsa_compliant_banner_image_ad_renderer":true,"enable_dsa_one_click_ata_translators_infeed_elements":true,"enable_exit_confirmation_dialog":true,"enable_exit_confirmation_dialog_web":true,"enable_free_preview_timer":true,"enable_game_info_dialog":true,"enable_gel_log_commands":true,"enable_get_account_switcher_endpoint_on_webfe":true,"enable_google_payment_billing_command_client_support":true,"enable_handle_search_on_channel_switcher":true,"enable_handles_account_menu_switcher":true,"enable_handles_in_mention_suggest_posts":true,"enable_high_frequency_cookie_rotation":true,"enable_hlp_client_icon_pick":true,"enable_horizontal_list_renderer_scroll_based_on_items_visibility":true,"enable_image_poll_post_creation":true,"enable_inline_shorts_on_wn":true,"enable_lcr_emoji_fountain":true,"enable_madison_search_migration":true,"enable_masthead_quartile_ping_fix":true,"enable_memberships_and_purchases":true,"enable_mentions_in_reposts":true,"enable_microformat_data":true,"enable_mini_app_csi_loggin ...
# setMessage({"ADDED_TO_QUEUE":"Added to queue","ADD_TO_DROPDOWN_LABEL":"Save to…","AD_BADGE_TEXT":"Ad","AD_TITLE":"Ad: $title.","BACK_ALT_LABEL":"Back","BACK_ONLINE":"Back online","CANCEL":"Cancel","CAPTION_OFF_TOAST":"Subtitles/CC turned off","CAPTION_ON_TOAST":"Subtitles/CC turned on","CHECK_CONNECTION_OR_DOWNLOADS":"Please check your connection or watch your downloaded videos.","CHIP_BAR_ALT_LABEL":"More videos","CLEAR":"Clear","CLOSE":"Close","CLOSED_CAPTIONS_DISABLED":"No subtitles are available for this video","COMMENT_LABEL":"Comment","CONNECT_TO_THE_INTERNET":"Connect to the Internet","CONTINUE_WATCHING":"Continue watching","DELETE":"Delete","DELETED_PLAYLIST":"Playlist deleted from downloads.","DELETED_VIDEO":"Video deleted from downloads.","DELETE_ALL_DOWNLOADS_PROMPT":"Delete all downloads?","DELETE_FROM_DOWNLOADS":"Remove from downloads","DELETING_ALL":"Downloads are being deleted","DISLIKE_LABEL":"Dislike","DISMISS":"Dismiss","DMA_CONSENT_CONFIRMATION":"Your choice will take effect on 6 March 2024. You can change your choices at any time in your Google Account.","DMA_CONSENT_GENERAL_ERROR":"Something went wrong while loading","DMA_CONSENT_RECORD_ERROR":"Something went wrong and your choices were not saved","DOWNLOAD":"Download","DOWNLOADED":"Downloaded","DOWNLOADING":"Downloading","DOWNLOADING_PERCENT":"Downloading… $percent%","DOWNLOADS":"Download","DOWNLOADS_AVAILABILITY":"Downloads remain available as long as your device has an active Internet connection at least once every 30 days.","DOWNLOADS_SETTINGS":"Download settings","DOWNLOAD_EXPIRED":"Download expired","DOWNLOAD_PAUSED":"Download paused","DOWNLOAD_QUALITY":"Download quality","DO_NOT_HAVE_DOWNLOADS":"You do not have any downloads","EDIT_AVATAR_LABEL":"Edit profile picture","EDU_GOT_IT":"Got It","END_OF_PLAYLIST":"End of playlist","ENTER_DATE_OR_EARLIER":"Enter $allowed_date or earlier","ENTER_DATE_OR_LATER":"Enter $allowed_date or later","FREEBIE_JOIN_MEMBERSHIP_EDU_TEXT":"This channel offers a membership which you can join for free with YouTube Premium","GET_PREMIUM":"Get Premium","GO_TO_DOWNLOADS":"Go to downloads","GUIDE_ALT_LABEL":"Guide","HORIZONTAL_LIST_NEXT_LABEL":"Next","HORIZONTAL_LIST_PREVIOUS_LABEL":"Previous","IMAGE_HORIZONTAL_POSITION_LABEL":"The centre of the preview is $x_percent% from the left and $y_percent% from the right.","IMAGE_VERTICAL_POSITION_LABEL":"The centre of the preview is $x_percent% from the top and $y_percent% from the bottom.","INVALID_DATE_ERROR":"Invalid date","JOIN_MEMBERSHIP_EDU_TEXT":"Get access to exclusive perks when you purchase a membership to this channel.","JOIN_MEMBERSHIP_EDU_TITLE":"Membership","KEEP_OPEN":"Keep this window open to continue","LIBRARY_GUIDE_ITEM_EDU_TEXT":"Find your history, playlists, purchases and more","LIBRARY_GUIDE_ITEM_EDU_TITLE":"Take a look at your new library","LIKE_LABEL":"Like","LOCAL_TIME_LABEL":"Local Time","LOGO_ALT_LABEL":"YouTube Home","MAIN_APP_WEB_COMMENT_TEASER_TOOLTIP":"Click here to read comments while watching the video.","MANAGE_MEMBERSHIP_EDU_TEXT":"Access your benefits and manage your membership from here.","MENTIONS_EDU_TEXT":"Go to the Help Centre to see how mentions work on YouTube.","MENTIONS_EDU_TITLE":"Learn more","MINIPLAYER_CLOSE":"Close player","MINIPLAYER_COLLAPSE_LABEL":"Collapse","MINIPLAYER_EXPAND_LABEL":"Expand","NEXT_VIDEO_LABEL":"Next video","NOT_NOW":"Not now","NO_ANGLE_BRACKET_LABEL":"Playlist title cannot contain \u003c or \u003e","NO_DOWNLOADS":"No downloads","NO_INTERNET_CONNECTION":"No Internet connection","OFFLINE_CHECK_CONNECTION":"You\u0027re offline. Check your connection.","PAUSE_DOWNLOADING":"Pause downloading","PLAYER_LABEL_MUTE":"Mute (m)","PLAYER_LABEL_PAUSE":"Pause (k)","PLAYER_LABEL_PLAY":"Play (k)","PLAYER_LABEL_UNMUTE":"Unmute (m)","PLAYLIST_NEXT_VIDEO_TITLE":"Next: $video_title","PLAY_ALL":"Play all","PREPARING_TO_DOWNLOAD":"Preparing to download…","PREVIOUS_VIDEO_LABEL":"Previous video","QUEUE":"Queue","QUEUE_CLEARED":"{count,plura ...
# </script><script nonce="cufSBo5PyXrS9OrHhOuGzA">if (window.ytcsi) {window.ytcsi.tick('lpcf', null, '');}</script><script src="https://www.youtube.com/s/desktop/dbf5c200/jsbin/scheduler.vflset/scheduler.js" nonce="cufSBo5PyXrS9OrHhOuGzA"></script><script src="https://www.youtube.com/s/desktop/dbf5c200/jsbin/www-i18n-constants-en_GB.vflset/www-i18n-constants.js" nonce="cufSBo5PyXrS9OrHhOuGzA"></script><script src="https://www.youtube.com/s/desktop/dbf5c200/jsbin/www-tampering.vflset/www-tampering.js" nonce="cufSBo5PyXrS9OrHhOuGzA"></script><script src="https://www.youtube.com/s/desktop/dbf5c200/jsbin/spf.vflset/spf.js" nonce="cufSBo5PyXrS9OrHhOuGzA"></script><script nonce="cufSBo5PyXrS9OrHhOuGzA">if(window["_spf_state"])window["_spf_state"].config={"assume-all-json-requests-chunked":true};
# </script><script src="https://www.youtube.com/s/desktop/dbf5c200/jsbin/network.vflset/network.js" nonce="cufSBo5PyXrS9OrHhOuGzA"></script><script nonce="cufSBo5PyXrS9OrHhOuGzA">if (window.ytcsi) {window.ytcsi.tick('csl', null, '');}</script><link rel="stylesheet" href="//fonts.googleapis.com/css2?family=Roboto:wght@300;400;500;700&family=YouTube+Sans:wght@300..900&display=swap" nonce="OCkdPJXbxa_is6UJxmtHRg"><script name="www-roboto" nonce="cufSBo5PyXrS9OrHhOuGzA">if (document.fonts && document.fonts.load) {document.fonts.load("400 10pt Roboto", ""); document.fonts.load("500 10pt Roboto", "");}</script><link rel="stylesheet" href="https://www.youtube.com/s/desktop/dbf5c200/cssbin/www-onepick.css" nonce="OCkdPJXbxa_is6UJxmtHRg"><link rel="stylesheet" href="https://www.youtube.com/s/_/ytmainappweb/_/ss/k=ytmainappweb.kevlar_base.Z3dC0u-eVQE.L.X.O/am=AIAC/d=0/br=1/rs=AGKMywFO_zdhwe3lHA3o0lORxI9c5dFryA" nonce="OCkdPJXbxa_is6UJxmtHRg"><style class="global_styles" nonce="OCkdPJXbxa_is6UJxmtHRg">body{padding:0;margin:0;overflow-y:scroll}body.autoscroll{overflow-y:auto}body.no-scroll{overflow:hidden}body.no-y-scroll{overflow-y:hidden}.hidden{display:none}textarea{--paper-input-container-input_-_white-space:pre-wrap}.grecaptcha-badge{visibility:hidden}</style><style class="masthead_shell" nonce="OCkdPJXbxa_is6UJxmtHRg">ytd-masthead.shell{background-color:#fff!important;position:fixed;top:0;right:0;left:0;display:-ms-flex;display:-webkit-flex;display:-webkit-box;display:-moz-box;display:-ms-flexbox;display:flex;height:56px;-ms-flex-align:center;-webkit-align-items:center;-webkit-box-align:center;-moz-box-align:center;align-items:center}ytd-masthead.shell #menu-icon{margin-left:16px}ytd-app>ytd-masthead.chunked{position:fixed;top:0;width:100%}ytd-masthead.shell.dark,ytd-masthead.shell.theater{background-color:#0f0f0f!important}ytd-masthead.shell.full-window-mode{background-color:#0f0f0f!important;opacity:0;-webkit-transform:translateY(calc(-100% - 5px));transform:translateY(calc(-100% - 5px))}ytd-masthead.shell>:first-child{padding-left:16px}ytd-masthead.shell>:last-child{padding-right:16px}ytd-masthead #masthead-logo{display:-ms-flex;display:-webkit-flex;display:-webkit-box;display:-moz-box;display:-ms-flexbox;display:flex}ytd-masthead #masthead-logo #country-code{margin-right:2px}ytd-masthead.shell #yt-logo-red-svg,ytd-masthead.shell #yt-logo-red-updated-svg,ytd-masthead.shell #yt-logo-svg,ytd-masthead.shell #yt-logo-updated-svg{-webkit-align-self:center;-ms-flex-item-align:center;align-self:center;margin-left:8px;padding:0;color:#000}ytd-masthead.shell #a11y-skip-nav{display:none}ytd-masthead.shell svg{width:40px;height:40px;padding:8px;margin-right:8px;-moz-box-sizing:border-box;box-sizing:border-box;color:#606060;fill:currentColor}ytd-masthead .external-icon{width:24px;height:24px}ytd-masthead .yt-icons-ext{fill:currentColor;color:#606060}ytd-masthead.shell.dark .yt-icons-ext ytd-masthead.shell.theater .yt-icons-ext{fill:#fff}ytd-masthead svg#yt-logo-svg{width:80px}ytd-masthead svg#yt-logo-red-svg{width:106.4px}ytd-masthead svg#yt-logo-updated-svg{width:90px}ytd-masthead svg#yt-logo-red-updated-svg{width:97px}@media (max-width:656px){ytd-masthead.shell>:first-child{padding-left:8px}ytd-masthead.shell>:last-child{padding-right:8px}ytd-masthead.shell svg{margin-right:0}ytd-masthead #masthead-logo{-ms-flex:1 1 0.000000001px;-webkit-flex:1;-webkit-box-flex:1;-moz-box-flex:1;flex:1;-webkit-flex-basis:0.000000001px;-ms-flex-preferred-size:0.000000001px;flex-basis:0.000000001px}ytd-masthead.shell #yt-logo-red-svg,ytd-masthead.shell #yt-logo-svg{margin-left:4px}}@media (min-width:876px){ytd-masthead #masthead-logo{width:129px}}#masthead-skeleton-icons{display:-webkit-box;display:-webkit-flex;display:-moz-box;display:-ms-flexbox;display:flex;-webkit-box-flex:1;-webkit-flex:1;-moz-box-flex:1;-ms-flex:1;flex:1;-webkit-box-orient:horizontal;-webkit-box-direction:normal;-webkit-flex-direction:row;-moz-box-orient:horizontal;-moz-box-direction:nor ...
# (function(e,c,l,f,g,h,k){var d=window;d.getInitialData=function(){var b=window;b.ytcsi&&b.ytcsi.tick("pr",null,"");b={page:e,endpoint:c,response:l};f&&(b.playerResponse=f);g&&(b.reelWatchSequenceResponse=g);k&&(b.url=k);h&&(b.previousCsn=h);return b};d.loadInitialData&&d.loadInitialData(d.getInitialData())})(a.ytPageType,a.ytCommand,a.ytInitialData,a.ytInitialPlayerResponse,a.ytInitialReelWatchSequenceResponse,a.ytPreviousCsn,a.ytUrl);
# })();</script><link rel="stylesheet" href="https://www.youtube.com/s/desktop/dbf5c200/cssbin/www-main-desktop-watch-page-skeleton.css" name="www-main-desktop-watch-page-skeleton" nonce="OCkdPJXbxa_is6UJxmtHRg"><div id="watch-page-skeleton" class="watch-skeleton  hidden"><div id="container"><div id="related"><div class="autoplay skeleton-light-border-bottom"><div id="upnext" class="skeleton-bg-color"></div><div class="video-skeleton"><div class="video-details"><div class="thumbnail skeleton-bg-color"></div><div class="details flex-1"><div class="video-title text-shell skeleton-bg-color"></div><div class="video-meta text-shell skeleton-bg-color"></div></div></div></div></div><div class="video-skeleton"><div class="video-details"><div class="thumbnail skeleton-bg-color"></div><div class="details flex-1"><div class="video-title text-shell skeleton-bg-color"></div><div class="video-meta text-shell skeleton-bg-color"></div></div></div></div><div class="video-skeleton"><div class="video-details"><div class="thumbnail skeleton-bg-color"></div><div class="details flex-1"><div class="video-title text-shell skeleton-bg-color"></div><div class="video-meta text-shell skeleton-bg-color"></div></div></div></div><div class="video-skeleton"><div class="video-details"><div class="thumbnail skeleton-bg-color"></div><div class="details flex-1"><div class="video-title text-shell skeleton-bg-color"></div><div class="video-meta text-shell skeleton-bg-color"></div></div></div></div><div class="video-skeleton"><div class="video-details"><div class="thumbnail skeleton-bg-color"></div><div class="details flex-1"><div class="video-title text-shell skeleton-bg-color"></div><div class="video-meta text-shell skeleton-bg-color"></div></div></div></div><div class="video-skeleton"><div class="video-details"><div class="thumbnail skeleton-bg-color"></div><div class="details flex-1"><div class="video-title text-shell skeleton-bg-color"></div><div class="video-meta text-shell skeleton-bg-color"></div></div></div></div><div class="video-skeleton"><div class="video-details"><div class="thumbnail skeleton-bg-color"></div><div class="details flex-1"><div class="video-title text-shell skeleton-bg-color"></div><div class="video-meta text-shell skeleton-bg-color"></div></div></div></div><div class="video-skeleton"><div class="video-details"><div class="thumbnail skeleton-bg-color"></div><div class="details flex-1"><div class="video-title text-shell skeleton-bg-color"></div><div class="video-meta text-shell skeleton-bg-color"></div></div></div></div><div class="video-skeleton"><div class="video-details"><div class="thumbnail skeleton-bg-color"></div><div class="details flex-1"><div class="video-title text-shell skeleton-bg-color"></div><div class="video-meta text-shell skeleton-bg-color"></div></div></div></div><div class="video-skeleton"><div class="video-details"><div class="thumbnail skeleton-bg-color"></div><div class="details flex-1"><div class="video-title text-shell skeleton-bg-color"></div><div class="video-meta text-shell skeleton-bg-color"></div></div></div></div></div><div id="info-container"><div id="primary-info" class="skeleton-light-border-bottom"><div id="title" class="text-shell skeleton-bg-color"></div><div id="info"><div id="count" class="text-shell skeleton-bg-color"></div><div class="flex-1"></div><div id="menu"><div class="menu-button skeleton-bg-color"></div><div class="menu-button skeleton-bg-color"></div><div class="menu-button skeleton-bg-color"></div><div class="menu-button skeleton-bg-color"></div><div class="menu-button skeleton-bg-color"></div></div></div></div><div id="secondary-info" class="skeleton-light-border-bottom"><div id="top-row"><div id="video-owner" class="flex-1"><div id="channel-icon" class="skeleton-bg-color"></div><div id="upload-info" class="flex-1"><div id="owner-name" class="text-shell skeleton-bg-color"></div><div id="published-date" class="text-shell skeleton-bg-color"></div></div></div><div id="subscribe-button" class=" ...

# %%
# !pip3 install youtube-search-python
# Out:
# Collecting youtube-search-python
#   Downloading youtube_search_python-1.6.6-py3-none-any.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 942.7 kB/s eta 0:00:001m761.0 kB/s eta 0:00:01
# Requirement already satisfied: httpx>=0.14.2 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from youtube-search-python) (0.24.1)
# Requirement already satisfied: certifi in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from httpx>=0.14.2->youtube-search-python) (2023.7.22)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from httpx>=0.14.2->youtube-search-python) (0.17.2)
# Requirement already satisfied: idna in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from httpx>=0.14.2->youtube-search-python) (3.4)
# Requirement already satisfied: sniffio in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from httpx>=0.14.2->youtube-search-python) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from httpcore<0.18.0,>=0.15.0->httpx>=0.14.2->youtube-search-python) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from httpcore<0.18.0,>=0.15.0->httpx>=0.14.2->youtube-search-python) (3.7.0)
# Requirement already satisfied: exceptiongroup in /Users/achethanreddy/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from anyio<5.0,>=3.0->httpcore<0.18.0,>=0.15.0->httpx>=0.14.2->youtube-search-python) (1.1.1)
# Installing collected packages: youtube-search-python
# Successfully installed youtube-search-python-1.6.6

# %%
from youtubesearchpython import VideosSearch

videosSearch = VideosSearch('Neck Pain', limit = 1)

res = videosSearch.result()

# %%
res['result'][0]['link']
# Out:
# 'https://www.youtube.com/watch?v=Hk5-7RFSsR0'

# %%
@app.post("/upload_pdf/")
async def upload_pdf(file: UploadFile = File(...)):
    url = 'https://css.na-1-dev.api.opentext.com/v2/content'
    access_token = get_auth_token()  # Replace with your actual access token
    user_dir = 'uploads'  # Replace with your desired user directory

    headers = {
        'Authorization': f'Bearer {access_token}'
    }

    files = {
        'file': (file.filename, file.file.read())
    }

    response = requests.post(url, headers=headers, files=files, verify=False)

    if response.status_code == 200:
        return {"message": "File uploaded successfully."}
    else:
        raise HTTPException(status_code=response.status_code, detail=f"Error uploading file. Status code: {response.status_code}")
